# %%
##BIBLIOTECAS UTILIZADAS: (SEABORN) (MATPLOTLIB) (PLOTLY) (PANDAS)

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %% [markdown]
# Analisando as têndências de imigração do Brasil

# %%
df.set_index("País", inplace=True) # --> Inplace usado para realizar a mudança na variável DF e não criar um dataframe novo

# %%
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %%
#CRIANDO UMA LISTA E TRANSFORMANDO OS ANOS DO INTERVALO EM STRING
anos = list(map(str, range(1980, 2014)))
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
##.iloc[número_do_índice] ou .iloc[número_do_índice, coluna] --> USADO PARA BUSCAR INFORMAÇÕES POR ÍNDICE
brasil = df.loc['Brasil', anos]
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
dados_brasil = {
    "Anos" : brasil.index,
    "Imigrantes": brasil.values
}
dados_brasil = pd.DataFrame(dados_brasil)
dados_brasil
# Out:
#     Anos Imigrantes
# 0   1980        211
# 1   1981        220
# 2   1982        192
# 3   1983        139
# 4   1984        145
# 5   1985        130
# 6   1986        205
# 7   1987        244
# 8   1988        394
# 9   1989        650
# 10  1990        650
# 11  1991        877
# 12  1992       1066
# 13  1993        866
# 14  1994        566
# 15  1995        572
# 16  1996        586
# 17  1997        591
# 18  1998        531
# 19  1999        626
# 20  2000        845
# 21  2001        847
# 22  2002        745
# 23  2003        839
# 24  2004        917
# 25  2005        969
# 26  2006       1181
# 27  2007       1746
# 28  2008       2138
# 29  2009       2509
# 30  2010       2598
# 31  2011       1508
# 32  2012       1642
# 33  2013       1714

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.plot(dados_brasil["Anos"], dados_brasil["Imigrantes"])
plt.title("Evolução da imigração do Brasil para o Canadá")
plt.xlabel("ANOS") ## --> RÓTULO DO EIXO X
plt.ylabel("IMIGRANTES") ## --> RÓTULO DO EIXO Y
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010']) # --> CRIA MARCAÇÕES PARA O EIXO 'X', ONDE USADO PARA DEIXAR OS ANOS CITADOS NA VISUALIZAÇÃO
plt.show()

# %% [markdown]
# **EXERCICIO 1:**
#
# "crie um gráfico de linhas comparando os números de imigrantes do Brasil e Argentina para o Canadá, que são os maiores países da América do Sul."

# %%
ex1_dados_brasil = df.loc["Brasil", anos]
ex1_dados_brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
ex1_dados_argentina = df.loc["Argentina", anos]
ex1_dados_argentina
# Out:
# 1980     368
# 1981     426
# 1982     626
# 1983     241
# 1984     237
# 1985     196
# 1986     213
# 1987     519
# 1988     374
# 1989     538
# 1990     678
# 1991     763
# 1992    1023
# 1993    1022
# 1994     366
# 1995     380
# 1996     396
# 1997     391
# 1998     349
# 1999     318
# 2000     427
# 2001     635
# 2002     865
# 2003    1745
# 2004    1591
# 2005    1153
# 2006     847
# 2007     620
# 2008     540
# 2009     467
# 2010     459
# 2011     278
# 2012     263
# 2013     282
# Name: Argentina, dtype: object

# %%
dados_paises = {
    "Anos" : anos,
    "Brasil": ex1_dados_brasil,
    "Argentina": ex1_dados_argentina
}

# %%
dados_paises = pd.DataFrame(dados_paises)

# %%
dados_paises
# Out:
#       Anos Brasil Argentina
# 1980  1980    211       368
# 1981  1981    220       426
# 1982  1982    192       626
# 1983  1983    139       241
# 1984  1984    145       237
# 1985  1985    130       196
# 1986  1986    205       213
# 1987  1987    244       519
# 1988  1988    394       374
# 1989  1989    650       538
# 1990  1990    650       678
# 1991  1991    877       763
# 1992  1992   1066      1023
# 1993  1993    866      1022
# 1994  1994    566       366
# 1995  1995    572       380
# 1996  1996    586       396
# 1997  1997    591       391
# 1998  1998    531       349
# 1999  1999    626       318
# 2000  2000    845       427
# 2001  2001    847       635
# 2002  2002    745       865
# 2003  2003    839      1745
# 2004  2004    917      1591
# 2005  2005    969      1153
# 2006  2006   1181       847
# 2007  2007   1746       620
# 2008  2008   2138       540
# 2009  2009   2509       467
# 2010  2010   2598       459
# 2011  2011   1508       278
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(dados_paises["Anos"], dados_paises["Brasil"], label="Brasil")
plt.plot(dados_paises["Anos"], dados_paises["Argentina"], label="Argentina")
plt.legend()
plt.title("Evolução da imigração do Brasil para o Canadá")
plt.xlabel("ANOS") ## --> RÓTULO DO EIXO X
plt.ylabel("IMIGRANTES") ## --> RÓTULO DO EIXO Y
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010']) # --> CRIA MARCAÇÕES PARA O EIXO 'X', ONDE USADO PARA DEIXAR OS ANOS CITADOS NA VISUALIZAÇÃO
plt.show()

# %% [markdown]
# **Finalização exercicio 1**
#
# **1 - Há alguma tendência ou padrão comum nos dados dos dois países?**
#
# Sim, os dois países tiveram a alta concentração de imigração no mesmo período, possivelmente causado por um fator que atinge a américa do sul
#
# **2 - Quais são os períodos com maior número de imigrantes nos dois países?**
#
# Argentina --> 2001 á 2005
#
# Brasil --> 2005 á 2010

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(dados_brasil['Anos'], dados_brasil['Imigrantes'])
ax.set_title('Evolução da imigração do Brasil para o Canadá\n 1980 á 2013')
ax.set_xlabel('Anos')
ax.set_ylabel('Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) ## (set_major_locator) --> utilizado para modificar o EIXO X da figura
plt.show()

# %%
## --> CRIANDO DOIS GRÁFICOS EM UMA LINHA PARA COMPARAÇÃO
fig, axs = plt.subplots(1, 2, figsize=(15,5)) # --> plt.subplots(numero_de_linhas, numero_de_graficos, tamanho_dos_graficos)
axs[0].plot(dados_brasil['Anos'], dados_brasil['Imigrantes'])
axs[0].set_title("Imigração do Brasil para o Canadá\n 1980 á 2013")
axs[0].set_xlabel('Anos')
axs[0].set_ylabel('Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()

axs[1].boxplot(dados_brasil['Imigrantes'])
axs[1].set_title("Boxplot da imigração do Brasil para o Canadá\n 1980 á 2013")
axs[1].set_xlabel('Anos')
axs[1].set_ylabel('Imigrantes')
axs[1].grid()

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
fig.subplots_adjust(hspace=0.5, wspace=0.5) # --> AJUSTA OS ESPAÇAMENTOS
plt.suptitle("Evolução da imigração de quatro países para o Canadá\n 1980 á 2013")

axs[0, 0].plot(df.loc['Brasil', anos])
axs[0, 0].set_title('Brasil')

axs[0, 1].plot(df.loc['Colômbia', anos])
axs[0, 1].set_title('Colômbia')

axs[1, 0].plot(df.loc['Argentina', anos])
axs[1, 0].set_title('Argentina')

axs[1, 1].plot(df.loc['Peru', anos])
axs[1, 1].set_title('Peru')

## FOR usado para fazer uma configuração em comum para todos os subplots
for ax in axs.flat:  #--> FLAT usado para percorrer todos os subplots
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))

## FOR usado para fazer uma configuração em comum para todos os subplots
for  ax in axs.flat:
  ax.set_xlabel('Anos')
  ax.set_ylabel('Imigrantes')

ymin = 0
ymax = 7000
for ax in axs.ravel(): ## --> RAVEL() utilizado para transformar um array bidimensional em unidimensional, assim podendo editar o eixo Y
  ax.set_ylim(ymin, ymax) # cetando limite para o eixo Y

plt.show()

# %% [markdown]
# **EXERCÍCIO 2**
#
# Como Analista de Dados, **crie uma figura com 4 subplots (2x2)** para mostrar a **variação das vendas em quatro lojas ao longo de um ano**. Cada subplot deve ser um gráfico de linhas representando as vendas mensais. Como você organizaria esses dados para facilitar a visualização?

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}
df_ex2 = pd.DataFrame(vendas_2022, index=lojas)
df_ex2
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
# --> CRIANDO AS SUBPLOTS PARA CRIAÇÃO DOS GRÁFICOS

fig, axs = plt.subplots(2,2,  figsize=(10,6))
fig.suptitle("Vendas do período de Janeiro a Dezembro de 2022 das Lojas A/B/C/D")
fig.subplots_adjust(hspace=0.5, wspace=0.5)

axs[0,0].plot(df_ex2.loc['A', :])
axs[0,0].set_title("Vendas de 2022 da Loja A")

axs[0,1].plot(df_ex2.loc['B', :])
axs[0,1].set_title("Vendas de 2022 da Loja B")

axs[1,0].plot(df_ex2.loc['C', :])
axs[1,0].set_title("Vendas de 2022 da Loja C")

axs[1,1].plot(df_ex2.loc['D', :])
axs[1,1].set_title("Vendas de 2022 da Loja D")


# --> FOR para customizar os subplots
for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(1))

ymin = 0
ymax = 400
for ax in axs.ravel():
  ax.set_ylim(ymin, ymax)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(dados_brasil['Anos'], dados_brasil['Imigrantes'], lw=3)
ax.set_title('Evolução da imigração do Brasil para o Canadá\n 1980 á 2013')
ax.set_xlabel('Anos')
ax.set_ylabel('Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) ## (set_major_locator) --> utilizado para modificar o EIXO X da figura
plt.show()

# %%
df_ex2.head()
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
df_ex2
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
america_sul = df.query('Região == "América do Sul"')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
america_sul_ordenado = america_sul.sort_values('Total', ascending=True) ## --> ORDENANDO O DATAFRAME DO MAIOR PARA O MENOR

# %%
america_sul_ordenado
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Venezuela  América Latina e o Caribe  América do Sul   103   117   174   124
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# ...

# %%
# america_sul_ordenado = america_sul_ordenado.set_index('País')

# %%
# --> COLOCANDO CORES NO NOSSO GRÁFICO DE BARRAS
cores = []

for pais in america_sul_ordenado.index:
  if pais == 'Brasil':
    cores.append('green')
  else:
    cores.append('gray')

fig, ax = plt.subplots(figsize=(12,5))
ax.barh(america_sul_ordenado.index, america_sul_ordenado['Total'], color=cores) #'AX.BAR' --> PARA BARRAS NA VERTICAL / AX.BARH --> PARA HORIZONTAL
ax.set_title('Imigração da América do Sul para o Canadá - Brasil foi o quarto país com mais imigrantes\n1980 a 2013', loc='center', fontsize=18)
ax.set_xlabel('Número de imigrantes', fontsize=15)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=8)

for i, v in enumerate(america_sul_ordenado['Total']):
  ax.text(v, i, str(v), color='black', fontsize=10, ha='left', va='center')

# ax.set_frame_on(False) #--> TIRAR O QUADRADO EM VOLTA DO GRÁFICO
# ax.get_xaxis().set_visible(False) #--> DEIXAR O ROTULOS DO EIXO X DESABILITADOS
ax.tick_params(axis='both', which='both', length=0) #--> TIRAR OS TRAÇOS EM VOLTA DOS FRAMES (WHICH -> DE QUAL EIXO QUERO TIRAR)
                                                    #--> (LENGHT -> QUAL O TAMANHO DO TRAÇO - ZERO PARA N APARECER)

# (dpi = qualidade da imagem) - (bbox_inches='tights' --> ajustar a nossa imagem com os limites do gráfico)
fig.savefig('Imigração _brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight')# --> Salvando nossa figura com os plots ou subplots

plt.show()

# %% [markdown]
# **UTILIZANDO BIBLIOTECA SEABORN **

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, x='Total', y= top_10.index, orient='h')
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set(title='Países com maior imigração para o Canadá',
      xlabel='Número de imigrantes',
      ylabel='')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h')

ax.set_title('Paises com maior imigração para o Canadá', loc='left', fontsize=16)
ax.set_xlabel("Imigrantes", fontsize=12)
ax.set_ylabel("")

plt.show()

# %%
# CRIANDO FUNÇÃO PARA A PALETA SER PASSADO VIA PARÂMETRO
def gerar_grafico_paleta(palette):
    fig, ax = plt.subplots(figsize=(8,4))
    ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h',palette=palette)
    ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
    ax.set_xlabel('Número de imigrantes', fontsize=14)
    ax.set_ylabel('')
    plt.show()

# %%
gerar_grafico_paleta('mako')
# Out:
# <ipython-input-40-176f55f95a2d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h',palette=palette)

# %%
gerar_grafico_paleta('rocket')
# Out:
# <ipython-input-40-176f55f95a2d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h',palette=palette)

# %%
sns.set_theme(style='white') # --> MUDANDO O TEMA DE FUNDO
gerar_grafico_paleta('mako_r')
# Out:
# <ipython-input-40-176f55f95a2d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h',palette=palette)

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='mako')

ax.set_title('Países com maior imigração para o Canadá\n1980 a 2013', loc='center', fontsize=18)
ax.set_xlabel('Número de Imigrantes', fontsize=14)
ax.set_ylabel('')
sns.despine() # --> TIRANDO O QUADRO DO GRÁFICO

plt.show()
# Out:
# <ipython-input-46-1d40267449b0>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', palette='mako')

# %% [markdown]
# EXERCÍCIO 4
#
# Criar uma figura contendo as tendências de imigração dos 4 maiores países da América latina: Brasil, Argentina, Peru e Colômbia.

# %%
df
# Out:
#                 Continente            Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia       Sul da Ásia    16    39    39    47    71
# Albânia             Europa     Sul da Europa     1     0     0     0     0
# Argélia             África   Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia         Polinésia     0     1     0     0     0
# Andorra             Europa     Sul da Europa     0     0     0     0     0
# ...                    ...               ...   ...   ...   ...   ...   ...
# Vietnã                Ásia  Sudeste Asiático  1191  1829  2162  3404  7583
# Saara Ocidental     África   Norte da África     0     0     0     0     0
# Iémen                 Ásia    Ásia Ocidental     1     2     1     6     0
# Zâmbia              África   África Oriental    11    17    11     7    16
# Zimbábue            África   África Oriental    72   114   102    44    32
#
# ...

# %%
fig, ax = plt.subplots(figsize=(12,5))

sns.set_palette('mako')

ax = sns.lineplot(data=america_sul_ordenado.loc['Brasil', anos], label='Brasil', lw=3)
ax = sns.lineplot(data=america_sul_ordenado.loc['Argentina', anos], label='Argentina', lw=3)
ax = sns.lineplot(data=america_sul_ordenado.loc['Colômbia', anos], label='Colômbia', lw=3)
ax = sns.lineplot(data=america_sul_ordenado.loc['Peru', anos], label='Peru', lw=3)

ax.set_title('Imigração dos maiores países da América do Sul para o Canadá\n ( 1980 á 2013)', loc='center', fontsize=12)
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('N° Imigrantes', fontsize=14)

ax.xaxis.set_major_locator(plt.MultipleLocator(5))

ax.legend()

plt.show()

# %% [markdown]
# Usando a biblioteca **PLOTLY** para criar visualizações dinâmicas

# %%
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='Anos', y='Imigrantes') # --> CRIANDO O GRÁFICO
fig.update_layout(width=1000, height=500, #--> DEFININDO A ALTURA E A LARGURA DO DO GRÁFICO
                  xaxis={'tickangle': -45}) # --> FAZENDO O EIXO X ROTACIONAR -45 GRAUS
fig.show() # PRINTANDO
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(dados_brasil, x='Anos', y='Imigrantes',
              title='Imigração do Brasil para o Canadá no período de 1980 a 2013')

fig.update_layout(
    width=1000, height=500,
    xaxis={'tickangle': -45},           #--> ROTACIONANDO O EIXO X EM -45 GRAUS
    font_family='Arial',                #--> MUDANDO A FONT DOS TEXTOS PARA ARIAL
    font_size=14,                       #--> AUMENTANDO A FONT PARA 14PX
    font_color='grey',                  #--> MUDANDO A COR DOS TEXTOS PARA CINZA
    title_font_color='black',           #--> MUDANDO A COR DO TÍTULO PARA PRETO
    title_font_size=22,                 #--> MUDANDO A FONT PARA 22PX
    xaxis_title='Ano',                  #--> COLOCANDO RÓTULO NO EIXO X
    yaxis_title='Número de imigrantes') #--> COLOCANDO RÓTULO NO EIXO Y
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
america_sul_ordenado
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Venezuela  América Latina e o Caribe  América do Sul   103   117   174   124
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# ...

# %%
#--> REMOVENDO AS COLUNAS QUE N UTILIZAREMOS DO DATAFRAME
df_america_sul_clean = america_sul_ordenado.drop(['Continente', 'Região', 'Total'], axis=1)
america_sul_final = df_america_sul_clean.T #--> REALIZANDO A TRANSPOSIÇÃO (TRANSFORMANDO COLUNA EM LINHAS E LINHAS EM COLUNAS)

# %%
america_sul_final
# Out:
# País  Suriname  Paraguai  Bolívia  Uruguai  Equador  Argentina  Venezuela  \
# 1980        15        45       44      128      238        368        103
# 1981        10        26       52      132      207        426        117
# 1982        21        32       42      146      184        626        174
# 1983        12        40       49      105      155        241        124
# 1984         5        48       38       90      179        237        142
# 1985        16        36       44       92      208        196        165
# 1986         7        34       79      137      240        213        179
# 1987        46        72      165      269      344        519        229
# 1988        16        53       63       99      265        374        279
# 1989        24        48       68      144      278        538        304
# 1990        26        56       71      111      552        678        344
# 1991        13        51      214      229      643        763        487
# ...

# %%
#REALIZADO TRAN


fig = px.line(america_sul_final, x=america_sul_final.index, y=america_sul_final.columns, color='País', markers=True,
              title='Imigração dos países da América do Sul para o Canadá de 1980 a 2013')
fig.update_layout(
    xaxis={'tickangle': -45},
    xaxis_title='Ano',
    yaxis_title='Número de imigrantes')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **EXERCICIO 5**
#
# **Dados de imigração do Brasil e Argentina**
#
# Duas linhas: uma para o Brasil e outra para a Argentina.
#
#
# Um botão "Play" para iniciar a animação, mostrando o aumento ou diminuição do número de imigrantes ao longo dos anos.
#
#
# As configurações de animação devem fazer com que as duas linhas sejam exibidas e animadas ao mesmo tempo.

# %%
ex5_dados_brasil = ex1_dados_brasil
ex5_dados_argentina = ex1_dados_argentina

# %%
ex5_dados_brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %%
# -->>>> EXERCÍCIO INCORRETO

import plotly.graph_objs as go

fig = go.Figure()

fig.add_trace(
    go.Scatter(x=[dados_brasil.iloc[0]], y=[dados_brasil.iloc[0]], mode='lines', name='Imigrantes - Brasil', line=dict(width=4))
)
fig.add_trace(
    go.Scatter(x=[ex5_dados_argentina.iloc[0]], y=[ex5_dados_argentina.iloc[0]], mode='lines', name='Imigrantes - Argentina', line=dict(width=5))
)

fig.update_layout(
    title=dict(
        text='<b>Imigração do Brasil e Argentina para o Canadá no período de 1980 a 2010</b>',
        x=0.12,
        xanchor='left',
        font=dict(size=20)
    ),
    xaxis=dict(range=[1980, 2013], autorange=False, title='<b>Ano</b>'),
    yaxis=dict(range=[0, 3000], autorange=False, title='<b>Número de imigrantes</b>'),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, {'frame': {'duration': 100, 'redraw': True}, 'fromcurrent': True}]
        )]
    )],
    width=1200,
    height=600
)

frames = []
for i in range(len(dados_brasil)):
    frame_data = [
        go.Scatter(x=ex5_dados_brasil.iloc[:i+1], y=ex5_dados_brasil.iloc[:i+1]),
        go.Scatter(x=ex5_dados_argentina.iloc[:i+1], y=ex5_dados_argentina.iloc[:i+1])
    ]
    frame = go.Frame(data=frame_data)
    frames.append(frame)
fig.frames = frames

fig.write_html('imigracao_argenina|_brasil.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
